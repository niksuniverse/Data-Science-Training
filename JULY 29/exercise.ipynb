# %% [markdown]
# Student Scores Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_id = '1v4XQjb5sBWR8KDJ7qumf01u-CH3oBn17'
url = f'https://drive.google.com/uc?id={file_id}'

# %%
df = pd.read_csv(url)
print(df.head())
# Out:
#     Name  Math  Science  English
# 0   Amit    78       85       74
# 1  Priya    92       89       96
# 2  Kiran    65       70       60
# 3  Anita    88       95       90
# 4   Ravi    55       60       58

# %% [markdown]
# 1)Read it into a pandas DataFrame and print the first 3 rows.

# %%
first_3_row=df.head(3)
print(first_3_row)
# Out:
#     Name  Math  Science  English
# 0   Amit    78       85       74
# 1  Priya    92       89       96
# 2  Kiran    65       70       60

# %% [markdown]
# 2. Calculate Average Scores
# Add a new column Average that calculates the mean score for Math, Science, and
# English for each student.

# %%
df=df.assign(Average=(df['Math']+df['Science']+df['English'])/3)
print(df)
# Out:
#     Name  Math  Science  English    Average
# 0   Amit    78       85       74  79.000000
# 1  Priya    92       89       96  92.333333
# 2  Kiran    65       70       60  65.000000
# 3  Anita    88       95       90  91.000000
# 4   Ravi    55       60       58  57.666667

# %% [markdown]
# Print the student with the highest average.

# %%
highest_avg = df[df['Average'] == df['Average'].max()]
print(highest_avg)
# Out:
#     Name  Math  Science  English    Average
# 1  Priya    92       89       96  92.333333

# %% [markdown]
# 3. Filter Students
# Display all students who have scored more than 80 in Science.

# %%
df=df[df['Science']>80]
print(df)
# Out:
#     Name  Math  Science  English    Average
# 0   Amit    78       85       74  79.000000
# 1  Priya    92       89       96  92.333333
# 3  Anita    88       95       90  91.000000

# %% [markdown]
# Display all students with an average score below 70.

# %%
df=df[df['Average']<70]
print(df)
# Out:
#     Name  Math  Science  English    Average
# 2  Kiran    65       70       60  65.000000
# 4   Ravi    55       60       58  57.666667

# %% [markdown]
# 4. Sorting
# Sort the students by English score (descending) and print the top 3.

# %%
df=df.sort_values(by='English',ascending=False).head(3)
print(df)
# Out:
#     Name  Math  Science  English    Average
# 1  Priya    92       89       96  92.333333
# 3  Anita    88       95       90  91.000000
# 0   Amit    78       85       74  79.000000

# %% [markdown]
# 5. Chart Exercise
# Create a bar chart showing students’ names on the X-axis and their average
# scores on the Y-axis.

# %%
import matplotlib.pyplot as plt

plt.bar(df['Name'], df['Average'])
plt.xlabel('Name')
plt.ylabel('Average Score')
plt.title('Students Average Scores')
plt.show()

# %% [markdown]
# Create a line chart for all students’ scores in Math, Science, and English (use
# df.plot() ).

# %%
import pandas as pd
import matplotlib.pyplot as plt
df.set_index('Name')[['Math', 'Science', 'English']].plot(kind='line', marker='o')
plt.title('Students Scores in Maths, Science , English')
plt.xlabel('Student Name')
plt.ylabel('Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# Bonus Task
# Find the subject with the highest total score across all students.

# %%
totals = df[['Math', 'Science', 'English']].sum()

top_subject = totals.idxmax()
top_score = totals.max()

print(f"Subject with the highest total score: {top_subject} ({top_score} marks)")
# Out:
# Subject with the highest total score: Science (399 marks)

# %% [markdown]
# Save the updated DataFrame (with Average column) as a new CSV named
# students_summary.csv .

# %%
df['Average'] = (df['Math'] + df['Science'] + df['English']) / 3

df.to_csv('students_summary.csv', index=False)

df.to_csv('/content/drive/MyDrive/students_summary.csv', index=False)
